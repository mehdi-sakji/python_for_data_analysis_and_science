# %% [markdown]
# # Parsing de Logs avec Python

# %% [markdown]
# ## Import de librairies

# %%
import elasticsearch
from elasticsearch import helpers
import datetime
# Out:
# /home/bigdatalover/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Parsing de Logs

# %% [markdown]
# On désire lire des Logs d'accès depuis un fichier, en extraire les informations utiles (URLs, type de requête, status de réponse...), puis structurer ces infos et les sauvegarder sous un index Elasticsearch (base de données avec fonctionnalités de moteur de recherche)

# %% [markdown]
# Ci-dessous, on lit (stream) le contenu du fichier de Logs et on le charge dans une liste où chaque élément est une ligne du fichier...

# %%
list_of_logs = []
with open("access.log", "r") as file:
    lines = file.readlines()

# %% [markdown]
# On instancie le client python Elasticsearch qui va permettre d,indexer les données depuis Python vers la base Elasticsearch. Préalablement, il faut avoir installé et démarré la base Elasticsearch (possible en mode un seul noeud)

# %%
ES_CLIENT = elasticsearch.Elasticsearch("localhost:9200", timeout=10000)

# %%
settings = {
    "mappings": {
        "logs": {
            "properties": {
                "IP": {"type": "keyword"},
                "Request": {"type": "keyword"},
                "Url": {"type": "keyword"},
                "Status": {"type": "keyword"},}}}}

# %% [markdown]
# On crée l'index où on veut stocker les Logs structurés avec les propriétés définies juste au dessus...

# %%
ES_CLIENT.indices.create(index="logs", ignore=400, body=settings)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'logs'}

# %% [markdown]
# Le code ci-dessous permet d'extraire les infos voulues en tokenisant chaque ligne de log (le pattern de splitting est l'espace " ") et identifiant les infos via leurs positions dans les tokens... <br>
# On met également ces infos dans le bon format qui permet de les passer en indexation vers Elasticsearch...

# %%
actions = []
current_id = 1
for line in lines[1:]:
    line_split = line.split(" ")
    action = {
        "_op_type": "update",
        "_index": "logs",
        "_type": "logs",
        "_id": current_id,
        "doc" : {
            "Date": datetime.datetime.strptime(
                "/".join(
                    [line_split[3].split("/")[1],
                     (line_split[3].split("/")[2]).split(":")[0]]), '%b/%Y'),
            "IP": line_split[0],
            "Request": line_split[5][1:],
            "Url": line_split[6],
            #"Status": int(line_split[8])
        },
        "doc_as_upsert" : True
    }
    try:
        action["doc"]["Status"] = int(line_split[8])
    except:
        pass
    actions.append(action)
    current_id += 1

# %%
actions
# Out:
# [{'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 1,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.169.248.247',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 2,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.169.248.247',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 3,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.177.4',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 4,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.177.4',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 5,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 6,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 7,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.29.198.15',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 8,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.29.198.15',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 9,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.184.11.34',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 10,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.184.11.34',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 11,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.227.29.79',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 12,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.227.29.79',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 13,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '90.154.66.233',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 14,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '90.154.66.233',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 15,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.140.24.131',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 16,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.140.24.131',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 17,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.188.245.16',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 18,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.188.245.16',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 19,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.213.133',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 20,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.213.133',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 21,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.204.119.130',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 22,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.204.119.130',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 23,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.35.0.41',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 24,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.35.0.41',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 25,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.252.165.97',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 26,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.252.165.97',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 27,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '31.202.233.212',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 28,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '31.202.233.212',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 29,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.219.151.232',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 30,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.219.151.232',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 31,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.184.174',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 32,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.184.174',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 33,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.116.138.82',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 34,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.116.138.82',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 35,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.47.189.163',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 36,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.47.189.163',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 37,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.44.144.231',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 38,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.44.144.231',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 39,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.134.32',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 40,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.134.32',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 41,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 42,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/css/bowslideshow.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 43,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/_system/css/general.css',
#    'Status': 404},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 44,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/media/system/js/caption.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 45,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/template.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 46,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/layout.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 47,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/menu.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 48,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/suckerfish.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 49,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/js/moomenu.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 50,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 51,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/media/system/js/mootools.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 52,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_01.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 53,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_02.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 54,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_03.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 55,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_06.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 56,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_04.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 57,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_05.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 58,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/logo.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 59,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_07.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 60,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/almhuette_raith.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 61,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/wohnraum.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 62,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/grillplatz.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 63,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/almenland_logo.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 64,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/oststeiermark.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 65,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/garage.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 66,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/steiermark_herz.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 67,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/images/image_shadow.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 68,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/content_heading.gif',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 69,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/bg_raith.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 70,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/module_heading.gif',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 71,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_02.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 72,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_04.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 73,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_05.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 74,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_06.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 75,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_03.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 76,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_01.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 77,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '191.182.199.16',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_07.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 78,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.212.187.84',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 79,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.212.187.84',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 80,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '180.180.104.183',
#    'Request': 'GET',
#    'Url': '/apache-log/access.log',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 81,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.194.214.104',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 82,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.194.214.104',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 83,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '189.16.1.18',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 84,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '189.16.1.18',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 85,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '177.6.184.110',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 86,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '177.6.184.110',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 87,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '81.88.222.215',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 88,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '81.88.222.215',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 89,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '66.249.66.19',
#    'Request': 'GET',
#    'Url': '/index.php?option=com_content&view=article&id=46&Itemid=54',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 90,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '87.255.246.50',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 91,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '87.255.246.50',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 92,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.116.249.142',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 93,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.116.249.142',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 94,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.39.229.183',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 95,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.39.229.183',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 96,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.185.236',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 97,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.72.185.236',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 98,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.248.235.103',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 99,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.248.235.103',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 100,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 101,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 102,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.252.11.47',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 103,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.252.11.47',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 104,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '2.93.207.163',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 105,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '2.93.207.163',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 106,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.34.161.222',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 107,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.34.161.222',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 108,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 109,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/css/bowslideshow.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 110,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/_system/css/general.css',
#    'Status': 404},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 111,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/template.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 112,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/layout.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 113,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/menu.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 114,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/css/suckerfish.css',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 115,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/media/system/js/caption.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 116,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/js/moomenu.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 117,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 118,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/media/system/js/mootools.js',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 119,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/logo.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 120,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_02.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 121,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/wohnraum.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 122,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_01.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 123,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/grillplatz.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 124,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/garage.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 125,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_03.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 126,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_06.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 127,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/almhuette_raith.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 128,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/modules/mod_bowslideshow/tmpl/images/image_shadow.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 129,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/content_heading.gif',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 130,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/templates/jp_hotel/images/module_heading.gif',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 131,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_05.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 132,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/almenland_logo.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 133,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/steiermark_herz.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 134,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_04.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 135,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/raith/oststeiermark.png',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 136,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/stories/slideshow/almhuette_raith_07.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 137,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/images/bg_raith.jpg',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 138,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.45.108.168',
#    'Request': 'GET',
#    'Url': '/favicon.ico',
#    'Status': 404},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 139,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.254.126.77',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 140,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '188.254.126.77',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 141,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.153.132.103',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 142,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.153.132.103',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 143,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '78.81.147.127',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 144,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '78.81.147.127',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 145,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.44.144.231',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 146,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.44.144.231',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 147,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '195.91.157.50',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 148,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '195.91.157.50',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 149,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.140.164.122',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 150,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.140.164.122',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 151,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.112.194.169',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 152,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '92.112.194.169',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 153,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '212.12.28.122',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 154,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '212.12.28.122',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 155,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '77.243.115.178',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 156,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '77.243.115.178',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 157,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '94.233.147.245',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 158,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '94.233.147.245',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 159,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '189.45.201.226',
#    'Request': 'GET',
#    'Url': '/apache-log/access.log',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 160,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.213.82.180',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 161,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.213.82.180',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 162,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '31.173.80.169',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 163,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '31.173.80.169',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 164,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.132.155',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 165,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.132.155',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 166,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '189.13.146.143',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 167,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '189.13.146.143',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 168,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '130.255.13.57',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 169,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '130.255.13.57',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 170,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.141.121.10',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 171,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.141.121.10',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 172,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '185.17.135.224',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 173,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '185.17.135.224',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 174,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.134.32',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 175,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '213.24.134.32',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 176,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '180.76.15.137',
#    'Request': 'GET',
#    'Url': '/robots.txt',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 177,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.252.11.47',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 178,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.252.11.47',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 179,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '37.215.38.205',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 180,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '37.215.38.205',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
# ...
#   '_id': 939,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.211.128.248',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 940,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.211.128.248',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 941,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.211.46.18',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 942,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '46.211.46.18',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 943,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '204.44.90.14',
#    'Request': 'GET',
#    'Url': '/apache-log/access.log',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 944,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '204.44.90.14',
#    'Request': 'GET',
#    'Url': '/robots.txt',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 945,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '94.19.17.65',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 946,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '94.19.17.65',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 947,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.32.68.29',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 948,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.32.68.29',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 949,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '85.173.94.97',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 950,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '85.173.94.97',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 951,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '177.201.52.125',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 952,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '177.201.52.125',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 953,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.166.200.19',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 954,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.166.200.19',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 955,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.122.96.106',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 956,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '62.122.96.106',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 957,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.218.92.2',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 958,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.218.92.2',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 959,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.219.156.45',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 960,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.219.156.45',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 961,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.194.74.20',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 962,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '176.194.74.20',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 963,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '130.255.13.57',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 964,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '130.255.13.57',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 965,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '87.117.38.218',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 966,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '87.117.38.218',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 967,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.166.200.19',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 968,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.166.200.19',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 969,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 970,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.167.113.100',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 971,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '77.244.21.14',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 972,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '77.244.21.14',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 973,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '2.86.149.141',
#    'Request': 'GET',
#    'Url': '/apache-log/access.log',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 974,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.184.11.34',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 975,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.184.11.34',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 976,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '2.93.22.237',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 977,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '2.93.22.237',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 978,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.106.142.176',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 979,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '109.106.142.176',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 980,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '195.8.51.14',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 981,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '195.8.51.14',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 982,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.214.187.254',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 983,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '91.214.187.254',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 984,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.227.6.83',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 985,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '5.227.6.83',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 986,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '37.1.206.196',
#    'Request': 'GET',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 987,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '37.1.206.196',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 988,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '37.1.206.196',
#    'Request': 'GET',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 989,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '89.145.141.195',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 990,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '89.145.141.195',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 991,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.32.85.147',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 992,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '95.32.85.147',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 993,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.220.236.21',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 994,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '83.220.236.21',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 995,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '89.178.243.193',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 996,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '89.178.243.193',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 997,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.35.29.219',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 998,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '178.35.29.219',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 999,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '93.185.22.218',
#    'Request': 'GET',
#    'Url': '/administrator/',
#    'Status': 200},
#   'doc_as_upsert': True},
#  {'_op_type': 'update',
#   '_index': 'logs',
#   '_type': 'logs',
#   '_id': 1000,
#   'doc': {'Date': datetime.datetime(2015, 12, 1, 0, 0),
#    'IP': '93.185.22.218',
#    'Request': 'POST',
#    'Url': '/administrator/index.php',
#    'Status': 200},
#   'doc_as_upsert': True},
#  ...]

# %% [markdown]
# Enfin, insère tout le batch de Logs dans Elasticsearch via la méthode <b> helpers.bulk() </b>

# %%
helpers.bulk(ES_CLIENT, actions)
# Out:
# (26311, [])
